# %% [markdown]
# # Importar pandas

# %%
import pandas as pd

# %% [markdown]
# # Ler DataFrame de arquivo csv

# %%
data = pd.read_csv('titanic/train.csv')

# %% [markdown]
# # Primeiras linhas

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Últimas linhas

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# # Informações do DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Resumo Estatístico de Campos Numéricos

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Resumo Estatístico de Campos Categóricos

# %%
data.describe(include='O')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# # Renomear colunas

# %%
data.rename({'Name': 'Nome', 'Sex': 'Sexo'}, axis=1, inplace=True)

# %% [markdown]
# # Selecionar coluna específica - DataFrame

# %%
data[['Nome', 'Sexo']].head()
# Out:
#                                                 Nome    Sexo
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %% [markdown]
# # Selecionando apenas uma coluna  Data Serious

# %%
data['Sexo']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sexo, Length: 891, dtype: object

# %% [markdown]
# # Funções mateáticas embutidas

# %%
data['Age'].mean()
# Out:
# 29.69911764705882

# %%
data['Age'].sum()
# Out:
# 21205.17

# %%
data['Age'].count()
# Out:
# 714

# %%
data['Age'].median()
# Out:
# 28.0

# %%
data['Age'].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
data['Age'].max()
# Out:
# 80.0

# %%
data['Age'].min() * 12
# Out:
# 5.04

# %%
data['Age'].idxmin()
# Out:
# 803

# %%
data['Age'].idxmax()
# Out:
# 630

# %%
data.mean()
# Out:
# C:\Users\phill\AppData\Local\Temp\ipykernel_5348\531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
data.sum()
# Out:
# C:\Users\phill\AppData\Local\Temp\ipykernel_5348\1263598667.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.sum()
# PassengerId                                               397386
# Survived                                                     342
# Pclass                                                      2057
# Nome           Braund, Mr. Owen HarrisCumings, Mrs. John Brad...
# Sexo           malefemalefemalefemalemalemalemalemalefemalefe...
# Age                                                     21205.17
# SibSp                                                        466
# Parch                                                        340
# Ticket         A/5 21171PC 17599STON/O2. 31012821138033734503...
# Fare                                                  28693.9493
# dtype: object

# %%
data.min()
# Out:
# C:\Users\phill\AppData\Local\Temp\ipykernel_5348\927168777.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.min()
# PassengerId                      1
# Survived                         0
# Pclass                           1
# Nome           Abbing, Mr. Anthony
# Sexo                        female
# Age                           0.42
# SibSp                            0
# Parch                            0
# Ticket                      110152
# Fare                           0.0
# dtype: object

# %% [markdown]
# # Selecionado pelo Index - iloc

# %%
data.iloc[630]
# Out:
# PassengerId                                     631
# Survived                                          1
# Pclass                                            1
# Nome           Barkworth, Mr. Algernon Henry Wilson
# Sexo                                           male
# Age                                            80.0
# SibSp                                             0
# Parch                                             0
# Ticket                                        27042
# Fare                                           30.0
# Cabin                                           A23
# Embarked                                          S
# Name: 630, dtype: object

# %%
data.iloc[803]
# Out:
# PassengerId                                804
# Survived                                     1
# Pclass                                       3
# Nome           Thomas, Master. Assad Alexander
# Sexo                                      male
# Age                                       0.42
# SibSp                                        0
# Parch                                        1
# Ticket                                    2625
# Fare                                    8.5167
# Cabin                                      NaN
# Embarked                                     C
# Name: 803, dtype: object

# %%
data.iloc[[630]]
# Out:
#      PassengerId  Survived  Pclass                                  Nome  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#      Sexo   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
data.iloc[[803]]
# Out:
#      PassengerId  Survived  Pclass                             Nome  Sexo  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C

# %%
data.iloc[[630,803]]
# Out:
#      PassengerId  Survived  Pclass                                  Nome  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 803          804         1       3       Thomas, Master. Assad Alexander
#
#      Sexo    Age  SibSp  Parch Ticket     Fare Cabin Embarked
# 630  male  80.00      0      0  27042  30.0000   A23        S
# 803  male   0.42      0      1   2625   8.5167   NaN        C

# %%
data.iloc[:1:-5]
# Out:
#      PassengerId  Survived  Pclass  \
# 890          891         0       3
# 885          886         0       3
# 880          881         1       2
# 875          876         1       3
# 870          871         0       3
# ..           ...       ...     ...
# 25            26         1       3
# 20            21         0       2
# 15            16         1       2
# 10            11         1       3
# 5              6         0       3
#
#                                                   Nome    Sexo   Age  SibSp  \
# 890                                Dooley, Mr. Patrick    male  32.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[['Nome', 'Age']].iloc[630]
# Out:
# Nome    Barkworth, Mr. Algernon Henry Wilson
# Age                                     80.0
# Name: 630, dtype: object

# %% [markdown]
# # Operador de seleção "Ioc"

# %%
data[['Age','Sexo', 'Nome', 'Fare', 'Pclass', 'Survived']].loc[data['Sexo']=='male'].head()
# Out:
#     Age  Sexo                            Nome     Fare  Pclass  Survived
# 0  22.0  male         Braund, Mr. Owen Harris   7.2500       3         0
# 4  35.0  male        Allen, Mr. William Henry   8.0500       3         0
# 5   NaN  male                Moran, Mr. James   8.4583       3         0
# 6  54.0  male         McCarthy, Mr. Timothy J  51.8625       1         0
# 7   2.0  male  Palsson, Master. Gosta Leonard  21.0750       3         0

# %%
data[['Age','Sexo', 'Nome', 'Fare', 'Pclass', 'Survived']].loc[data['Age']<=20].tail()
# Out:
#       Age    Sexo                              Nome     Fare  Pclass  Survived
# 869   4.0    male   Johnson, Master. Harold Theodor  11.1333       3         1
# 875  15.0  female  Najib, Miss. Adele Kiamie "Jane"   7.2250       3         1
# 876  20.0    male     Gustafsson, Mr. Alfred Ossian   9.8458       3         0
# 877  19.0    male              Petroff, Mr. Nedelio   7.8958       3         0
# 887  19.0  female      Graham, Miss. Margaret Edith  30.0000       1         1

# %% [markdown]
# # Selecionando com múltiplas condições "loc"

# %%
data[['Age','Sexo', 'Nome', 'Fare', 'Pclass', 'Survived']]\
.loc[(data['Age'] >=3) & (data['Age'] <= 10) & (data['Sexo'] == 'female')].head()
# Out:
#      Age    Sexo                                      Nome     Fare  Pclass  \
# 10   4.0  female           Sandstrom, Miss. Marguerite Rut  16.7000       3
# 24   8.0  female             Palsson, Miss. Torborg Danira  21.0750       3
# 43   3.0  female  Laroche, Miss. Simonne Marie Anne Andree  41.5792       2
# 58   5.0  female              West, Miss. Constance Mirium  27.7500       2
# 147  9.0  female          Ford, Miss. Robina Maggie "Ruby"  34.3750       3
#
#      Survived
# 10          1
# 24          0
# 43          1
# 58          1
# 147         0

# %%
data[['Age','Sexo', 'Nome', 'Fare', 'Pclass', 'Survived']]\
.loc[(data['Age'] >=3) & (data['Age'] <= 10) & (data['Sexo'] == 'female') & ~(data['Survived']==1)].head()
# Out:
#       Age    Sexo                                  Nome    Fare  Pclass  \
# 24    8.0  female         Palsson, Miss. Torborg Danira  21.075       3
# 147   9.0  female      Ford, Miss. Robina Maggie "Ruby"  34.375       3
# 374   3.0  female            Palsson, Miss. Stina Viola  21.075       3
# 419  10.0  female             Van Impe, Miss. Catharina  24.150       3
# 541   9.0  female  Andersson, Miss. Ingeborg Constanzia  31.275       3
#
#      Survived
# 24          0
# 147         0
# 374         0
# 419         0
# 541         0

# %% [markdown]
# # map e replace

# %%
data['Sexo'].map({'male': 'homem', 'female': 'mulher'}).head()
# Out:
# 0     homem
# 1    mulher
# 2    mulher
# 3    mulher
# 4     homem
# Name: Sexo, dtype: object

# %%
data['Sexo'].replace({'male': 'homem', 'female': 'mulher'}).head()
# Out:
# 0     homem
# 1    mulher
# 2    mulher
# 3    mulher
# 4     homem
# Name: Sexo, dtype: object

# %%
data['Sexo'].replace(['male', 'female'],['homem', 'mulher']).head()
# Out:
# 0     homem
# 1    mulher
# 2    mulher
# 3    mulher
# 4     homem
# Name: Sexo, dtype: object

# %%
data['Sexo'] = data['Sexo'].map({'male': 'homem', 'female': 'mulher'})

# %% [markdown]
# # Group by

# %%
data.groupby('Sexo').mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sexo
# homem    454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
# mulher   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
#
#              Fare
# Sexo
# homem   25.523893
# mulher  44.479818

# %%
data.groupby('Survived').mean()
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408

# %%
data.loc[data['Age'] > 50].groupby('Survived').mean()
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          399.880952  1.714286  59.380952  0.119048  0.285714  34.478574
# 1          527.863636  1.227273  57.454545  0.500000  0.318182  61.027650

# %%
data.loc[(data['Age'] > 50) & (data['Survived'] == 1)].groupby(['Sexo','Survived','Pclass']).mean()
# Out:
#                         PassengerId        Age     SibSp     Parch       Fare
# Sexo   Survived Pclass
# homem  1        1        635.000000  59.800000  0.200000  0.200000  40.350000
#                 2        571.000000  62.000000  0.000000  0.000000  10.500000
# mulher 1        1        507.076923  56.230769  0.692308  0.230769  83.213138
#                 2        395.500000  54.500000  0.500000  1.500000  19.500000
#                 3        484.000000  63.000000  0.000000  0.000000   9.587500

# %% [markdown]
# # Crosstab

# %%
pd.crosstab(data['Survived'], data['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
pd.crosstab(data['Survived'], data['Pclass'], margins=True)
# Out:
# Pclass      1    2    3  All
# Survived
# 0          80   97  372  549
# 1         136   87  119  342
# All       216  184  491  891

# %%
pd.crosstab(data['Survived'], data['Sexo'], margins=True).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_1db73_row0_col0 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_1db73_row0_col1, #T_1db73_row1_col0, #T_1db73_row1_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_1db73_row0_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_1db73_row1_col1 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_1db73_row2_col0, #T_1db73_row2_col1, #T_1db73_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1db73">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Sexo</th>
#       <th id="T_1db73_level0_col0" class="col_heading level0 col0" >homem</th>
#       <th id="T_1db73_level0_col1" class="col_heading level0 col1" >mulher</th>
#       <th id="T_1db73_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
pd.crosstab(data['Survived'], data['Sexo'], margins=True).style.background_gradient(cmap='OrRd')
# Out:
# <style type="text/css">
# #T_575b1_row0_col0 {
#   background-color: #d2291a;
#   color: #f1f1f1;
# }
# #T_575b1_row0_col1, #T_575b1_row1_col0, #T_575b1_row1_col2 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_575b1_row0_col2 {
#   background-color: #fdba83;
#   color: #000000;
# }
# #T_575b1_row1_col1 {
#   background-color: #e9583e;
#   color: #f1f1f1;
# }
# #T_575b1_row2_col0, #T_575b1_row2_col1, #T_575b1_row2_col2 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_575b1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Sexo</th>
#       <th id="T_575b1_level0_col0" class="col_heading level0 col0" >homem</th>
#       <th id="T_575b1_level0_col1" class="col_heading level0 col1" >mulher</th>
#       <th id="T_575b1_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
pd.crosstab(data['Survived'], data['Sexo'], margins=True).style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_de16a_row0_col0 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_de16a_row0_col1, #T_de16a_row1_col0, #T_de16a_row1_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_de16a_row0_col2 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_de16a_row1_col1 {
#   background-color: #3aa357;
#   color: #f1f1f1;
# }
# #T_de16a_row2_col0, #T_de16a_row2_col1, #T_de16a_row2_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_de16a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Sexo</th>
#       <th id="T_de16a_level0_col0" class="col_heading level0 col0" >homem</th>
#       <th id="T_de16a_level0_col1" class="col_heading level0 col1" >mulher</th>
#       <th id="T_de16a_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %% [markdown]
# # Ordenando dados

# %%
data.loc[(data['Age'] > 0)].sort_values('Age')
# Out:
#      PassengerId  Survived  Pclass                                  Nome  \
# 803          804         1       3       Thomas, Master. Assad Alexander
# 755          756         1       2             Hamalainen, Master. Viljo
# 644          645         1       3                Baclini, Miss. Eugenie
# 469          470         1       3         Baclini, Miss. Helene Barbara
# 78            79         1       2         Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                   ...
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 851          852         0       3                   Svensson, Mr. Johan
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#        Sexo    Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %%
data.loc[(data['Age'] > 0)].sort_index(ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 890          891         0       3
# 889          890         1       1
# 887          888         1       1
# 886          887         0       2
# 885          886         0       3
# ..           ...       ...     ...
# 4              5         0       3
# 3              4         1       1
# 2              3         1       3
# 1              2         1       1
# 0              1         0       3
#
#                                                   Nome    Sexo   Age  SibSp  \
# 890                                Dooley, Mr. Patrick   homem  32.0      0
# 889                              Behr, Mr. Karl Howell   homem  26.0      0
# 887                       Graham, Miss. Margaret Edith  mulher  19.0      0
# 886                              Montvila, Rev. Juozas   homem  27.0      0
# 885               Rice, Mrs. William (Margaret Norton)  mulher  39.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Lidando comn dados faltando -> NaN - Not a Number

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Nome             0
# Sexo             0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.loc[data['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Nome  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#        Sexo   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   mulher  38.0      0      0  113572  80.0   B28      NaN
# 829  mulher  62.0      0      0  113572  80.0   B28      NaN

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
data.describe(include='O')
# Out:
#                            Nome   Sexo  Ticket    Cabin Embarked
# count                       891    891     891      204      889
# unique                      891      2     681      147        3
# top     Braund, Mr. Owen Harris  homem  347082  B96 B98        S
# freq                          1    577       7        4      644

# %%
data['Embarked'].fillna('S', inplace=)
# Out:
#   File "C:\Users\phill\AppData\Local\Temp\ipykernel_5348\2363565130.py", line 1
#     data['Embarked'].fillna('S', inplace=)
#                                          ^
# SyntaxError: invalid syntax

# %%
data['Embarked'].isnull().sum()
# Out:
# 2

# %%
    data['Embarked'].at[61] = 'S'

# %%
data['Embarked'].at[61]
# Out:
# 'S'

# %%
data['Embarked'].at[829] = 'S'

# %% [markdown]
# # Deletando coluna ou linha

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Nome             0
# Sexo             0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
data.drop('Sexo', axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Nome   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
data.drop(1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Nome    Sexo   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris   homem  22.0      1      0
# 2                          Heikkinen, Miss. Laina  mulher  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher  35.0      1      0
# 4                        Allen, Mr. William Henry   homem  35.0      0      0
# 5                                Moran, Mr. James   homem   NaN      0      0
# ...

# %%
data.drop(['Sexo','PassengerId','Survived'], axis=1)
# Out:
#      Pclass                                               Nome   Age  SibSp  \
# 0         3                            Braund, Mr. Owen Harris  22.0      1
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
# 2         3                             Heikkinen, Miss. Laina  26.0      0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1
# 4         3                           Allen, Mr. William Henry  35.0      0
# ..      ...                                                ...   ...    ...
# 886       2                              Montvila, Rev. Juozas  27.0      0
# 887       1                       Graham, Miss. Margaret Edith  19.0      0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"   NaN      1
# 889       1                              Behr, Mr. Karl Howell  26.0      0
# 890       3                                Dooley, Mr. Patrick  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # Apply e lambda

# %%
data['Age'].apply(lambda x: x > 80)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
x = '112053'

# %%
x[:-1]
# Out:
# '11205'

# %%
data['Ticket'].apply(lambda x: x[:-1])
# Out:
# 0             A/5 2117
# 1              PC 1759
# 2      STON/O2. 310128
# 3                11380
# 4                37345
#             ...
# 886              21153
# 887              11205
# 888          W./C. 660
# 889              11136
# 890              37037
# Name: Ticket, Length: 891, dtype: object

# %% [markdown]
# # Variáveis Dummy

# %%
pd.get_dummies(data, columns=['Sexo', 'Embarked'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Nome   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
pd.get_dummies(data, columns=['Sexo'], drop_first=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Nome   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
pd.get_dummies(data, columns=['Embarked'], drop_first=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Nome    Sexo   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   homem  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher  38.0      1
# 2                               Heikkinen, Miss. Laina  mulher  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher  35.0      1
# 4                             Allen, Mr. William Henry   homem  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Concatenando DataFrames

# %%
data = pd.get_dummies(data, columns=['Sexo'], drop_first=True)

# %%
embarque = pd.get_dummies(data['Embarked'], drop_first=True)

# %%
embarque.head()
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1

# %%
data.shape, embarque.shape
# Out:
# ((891, 12), (891, 2))

# %%
data = pd.concat([data, embarque], axis=1)

# %%
data.shape
# Out:
# (891, 14)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Nome   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
data.drop('Embarked', axis=1, inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Nome   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %% [markdown]
# # Regex

# %%
data['Titulo'] = data['Nome'].str.extract('([a-z,A-Z]+)\.')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Nome   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %% [markdown]
# # Engenharia de Recursos - Feature Engineering

# %%
data['Sexo'] = data['Sexo_mulher'].map({0: 'Homem', 1: 'Mulher'})

# %%
pd.crosstab(data['Titulo'], data['Sexo'])
# Out:
# Sexo      Homem  Mulher
# Titulo
# Capt          1       0
# Col           2       0
# Countess      0       1
# Don           1       0
# Dr            6       1
# Jonkheer      1       0
# Lady          0       1
# Major         2       0
# Master       40       0
# Miss          0     182
# Mlle          0       2
# Mme           0       1
# Mr          517       0
# Mrs           0     125
# Ms            0       1
# Rev           6       0
# Sir           1       0

# %%
data['Titulo'] = data['Titulo'].apply(lambda x: 'Outros' if x not in ['Master','Mrs', 'Miss','Mr'] else x)

# %%
pd.crosstab(data['Titulo'], data['Sexo'])
# Out:
# Sexo    Homem  Mulher
# Titulo
# Master     40       0
# Miss        0     182
# Mr        517       0
# Mrs         0     125
# Outros     20       7

# %%
data[['Titulo', 'Sexo', 'Age', 'Survived']].loc[data['Titulo']=='Master']
# Out:
#      Titulo   Sexo    Age  Survived
# 7    Master  Homem   2.00         0
# 16   Master  Homem   2.00         0
# 50   Master  Homem   7.00         0
# 59   Master  Homem  11.00         0
# 63   Master  Homem   4.00         0
# 65   Master  Homem    NaN         1
# 78   Master  Homem   0.83         1
# 125  Master  Homem  12.00         1
# 159  Master  Homem    NaN         0
# 164  Master  Homem   1.00         0
# 165  Master  Homem   9.00         1
# 171  Master  Homem   4.00         0
# 176  Master  Homem    NaN         0
# 182  Master  Homem   9.00         0
# 183  Master  Homem   1.00         1
# 193  Master  Homem   3.00         1
# 261  Master  Homem   3.00         1
# 278  Master  Homem   7.00         0
# 305  Master  Homem   0.92         1
# 340  Master  Homem   2.00         1
# 348  Master  Homem   3.00         1
# 386  Master  Homem   1.00         0
# 407  Master  Homem   3.00         1
# 445  Master  Homem   4.00         1
# 480  Master  Homem   9.00         0
# ...

# %%
data[['Titulo', 'Sexo', 'Age', 'Survived']].loc[data['Titulo']=='Master'].max()
# Out:
# Titulo      Master
# Sexo         Homem
# Age           12.0
# Survived         1
# dtype: object

# %%
data[['Titulo', 'Sexo', 'Age', 'Survived']].loc[data['Titulo']=='Master'].min()
# Out:
# Titulo      Master
# Sexo         Homem
# Age           0.42
# Survived         0
# dtype: object

# %%
data[['Titulo', 'Sexo', 'Age', 'Survived']].loc[data['Titulo']=='Master'].mean()
# Out:
# C:\Users\phill\AppData\Local\Temp\ipykernel_5348\3427087015.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data[['Titulo', 'Sexo', 'Age', 'Survived']].loc[data['Titulo']=='Master'].mean()
# Age         4.574167
# Survived    0.575000
# dtype: float64

# %% [markdown]
# # Mudando valores linha por linha - iterrows()

# %%
cabine = pd.read_csv('titanic/train.csv')

# %%
cabine['Cabin'].head()

# %%
for idx, _ in cabine[['Cabin']].dropna().iterrows():
    cabine_individual = data['Cabin'].at[idx]
    cabine['Cabin'].at[idx] = cabine_individual[0]

# %%
cabine[['Cabin', 'Survived', 'Age', 'Pclass']].dropna().groupby(['Cabin', 'Sex']).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5348\1909965184.py in <module>
# ----> 1 cabine[['Cabin', 'Survived', 'Age', 'Pclass']].dropna().groupby(['Cabin', 'Sex']).mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7719         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7720         # "Union[bool, NoDefault]"; expected "bool"
# -> 7721         return DataFrameGroupBy(
#    7722             obj=self,
#    7723             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     880             from pandas.core.groupby.grouper import get_grouper
# ...
